# %% [markdown]
# <a href="https://colab.research.google.com/github/HSYhrae/TIL/blob/master/%EA%B5%AC%EA%B8%80%EB%A7%B5%EC%82%AC%EC%9A%A9(%EC%9C%84).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
unique_loc_up = pd.read_csv('/content/drive/MyDrive/data/3team_project/전월세가/서울특별시_전월세가_윗부분.csv')
unique_loc_up
# Out:
#        Year  Month  Region_Code Region_Name  KA_Code KA_Name  LNA_Code  \
# 0      2011      4        11170         용산구    11300   원효로2가         1
# 1      2011      2        11440         마포구    11000    노고산동         1
# 2      2011      7        11650         서초구    10100     방배동         1
# 3      2011      1        11620         관악구    10300     남현동         1
# 4      2011      2        11440         마포구    11000    노고산동         1
# ...     ...    ...          ...         ...      ...     ...       ...
# 46984  2012      8        11170         용산구    13000    이태원동         1
# 46985  2012      2        11440         마포구    12000     서교동         1
# 46986  2012      8        11380         은평구    10400     갈현동         1
# 46987  2012      6        11230        동대문구    10600     장안동         1
# 46988  2012     12        11530         구로구    10700     개봉동         1
#
#       LNA_Name  Main_num  Sub_num  ...  Population    IR   UR  LC_index  \
# ...

# %%
# !pip install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40713 sha256=4b13056a37e14d5bdc9ed50e4acaf35c57a76d65363184b49a93fbf5bf6b1f12
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# ...

# %%
import googlemaps
from datetime import datetime

apikey = 'AIzaSyABh7Z1cDdpLu_bAU1hiyluk5RUoQBVAfg'

def getLoc(addr):
    gmaps = googlemaps.Client(key='AIzaSyABh7Z1cDdpLu_bAU1hiyluk5RUoQBVAfg')
    geocode_result = gmaps.geocode(addr)
    n_lat = geocode_result[0]['geometry']['location']['lat']
    n_lng = geocode_result[0]['geometry']['location']['lng']
    loc = {'lat':n_lat, 'lng':n_lng}
    return loc

# 함수 설정을 통해 구글 지오코드 서비스로 위도 경도에 대한 데이터 가져온 후
# 실거래가 데이터 프레임의 "주소" 컬럼의 주소 값들을 기반으로 위도, 경도 위치 데이터 받은 후
# "위도", "경도"에 컬럼값 위치 데이터 넣기

# %%
for i in range(46870, 46989):
    find = unique_loc_up.loc[i, "address"]
    sub_lat = getLoc(find)['lat']
    sub_long = getLoc(find)['lng']
    unique_loc_up.loc[i, '위도'] = sub_lat
    unique_loc_up.loc[i, '경도'] = sub_long

unique_loc_up.tail(3)
# Out:
#        Year  Month  Region_Code Region_Name  KA_Code KA_Name  LNA_Code  \
# 46986  2012      8        11380         은평구    10400     갈현동         1
# 46987  2012      6        11230        동대문구    10600     장안동         1
# 46988  2012     12        11530         구로구    10700     개봉동         1
#
#       LNA_Name  Main_num  Sub_num  ...  Population    IR   UR  LC_index  \
# 46986       대지       448       35  ...    489536.0  3.00  3.0      74.5
# 46987       대지       410       13  ...    357595.0  3.25  3.2      74.5
# 46988       대지       153       14  ...    422946.0  2.75  2.9      75.3
#
#        CA_index  TC_index   SDT_index HSP_index         위도          경도
# 46986      81.1      78.6  101.686418      73.6  37.620084  126.913733
# 46987      81.1      78.3         NaN      75.2  37.563718  127.060087
# 46988      82.1      79.4  109.252507      72.1  37.500225  126.855209
#
# [3 rows x 29 columns]

# %%
unique_loc_up.to_csv('/content/drive/MyDrive/data/3team_project/전월세가/서울특별시_전월세가_윗부분(완성).csv', encoding='utf-8', index=False)
