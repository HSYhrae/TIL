# %% [markdown]
# <a href="https://colab.research.google.com/github/HSYhrae/TIL/blob/master/%EA%B5%AC%EA%B8%80%EB%A7%B5%EC%82%AC%EC%9A%A9(%EC%95%84%EB%9E%98).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
unique_loc_down = pd.read_csv('/content/drive/MyDrive/data/3team_project/전월세가/서울특별시_전월세가_아랫부분.csv')
unique_loc_down
# Out:
#        Year  Month  Region_Code Region_Name  KA_Code KA_Name  LNA_Code  \
# 0      2012      7        11710         송파구    10800     문정동         1
# 1      2012      3        11200         성동구    11500   성수동2가         1
# 2      2012      2        11320         도봉구    10800     도봉동         1
# 3      2012      1        11500         강서구    10100     염창동         1
# 4      2012      1        11710         송파구    10800     문정동         1
# ...     ...    ...          ...         ...      ...     ...       ...
# 49995  2022     12        11215         광진구    10100     중곡동         1
# 49996  2022     12        11305         강북구    10100     미아동         1
# 49997  2022     12        11545         금천구    10300     시흥동         1
# 49998  2022     12        11440         마포구    12400     연남동         1
# 49999  2022     12        11710         송파구    11300     거여동         1
#
#       LNA_Name  Main_num  Sub_num  ...  Population    IR   UR  LC_index  \
# ...

# %%
# !pip install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40713 sha256=7e072e7370dcd1f526228da0f96eeaa4d869907689e2a428b22a81de63a4e280
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# ...

# %%
import googlemaps
from datetime import datetime

apikey = 'AIzaSyABh7Z1cDdpLu_bAU1hiyluk5RUoQBVAfg'

def getLoc(addr):
    gmaps = googlemaps.Client(key='AIzaSyABh7Z1cDdpLu_bAU1hiyluk5RUoQBVAfg')
    geocode_result = gmaps.geocode(addr)
    n_lat = geocode_result[0]['geometry']['location']['lat']
    n_lng = geocode_result[0]['geometry']['location']['lng']
    loc = {'lat':n_lat, 'lng':n_lng}
    return loc

# 함수 설정을 통해 구글 지오코드 서비스로 위도 경도에 대한 데이터 가져온 후
# 실거래가 데이터 프레임의 "주소" 컬럼의 주소 값들을 기반으로 위도, 경도 위치 데이터 받은 후
# "위도", "경도"에 컬럼값 위치 데이터 넣기

# %%
for i in unique_loc_down.index:
    find = unique_loc_down.loc[i, "address"]
    sub_lat = getLoc(find)['lat']
    sub_long = getLoc(find)['lng']
    unique_loc_down.loc[i, '위도'] = sub_lat
    unique_loc_down.loc[i, '경도'] = sub_long

unique_loc_down.head
# Out:
# <bound method NDFrame.head of        Year  Month  Region_Code Region_Name  KA_Code KA_Name  LNA_Code  \
# 0      2012      7        11710         송파구    10800     문정동         1
# 1      2012      3        11200         성동구    11500   성수동2가         1
# 2      2012      2        11320         도봉구    10800     도봉동         1
# 3      2012      1        11500         강서구    10100     염창동         1
# 4      2012      1        11710         송파구    10800     문정동         1
# ...     ...    ...          ...         ...      ...     ...       ...
# 49995  2022     12        11215         광진구    10100     중곡동         1
# 49996  2022     12        11305         강북구    10100     미아동         1
# 49997  2022     12        11545         금천구    10300     시흥동         1
# 49998  2022     12        11440         마포구    12400     연남동         1
# 49999  2022     12        11710         송파구    11300     거여동         1
#
#       LNA_Name  Main_num  Sub_num  ...  Population    IR   UR  LC_index  \
# ...

# %%
unique_loc_down.to_csv('/content/drive/MyDrive/data/3team_project/전월세가/서울특별시_전월세가_아랫부분(완성).csv', encoding='utf-8', index=False)
